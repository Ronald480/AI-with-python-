# %% [markdown]
# # Part 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
import sklearn.tree as tree

# %%
# Step 1: Load and exploring the dataset
loan = pd.read_csv('loan.csv')
loan.head(10)
# Out:
#    Income  Loan Amount Default
# 0      15            8      No
# 1      30            8      No
# 2       5            9     Yes
# 3      22           10      No
# 4      33           12      No
# 5      18           15      No
# 6      28           20      No
# 7      12           21     Yes
# 8      24           22     Yes
# 9       9           30     Yes

# %%
loan.info()     # Summary of data
sb.boxplot(loan, x ='Default', y ='Income')     # Box plot
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Income       30 non-null     int64
#  1   Loan Amount  30 non-null     int64
#  2   Default      30 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 852.0+ bytes
# <Axes: xlabel='Default', ylabel='Income'>

# %%
sb.scatterplot(loan, x= 'Loan Amount', y= 'Income', hue ='Default', markers=["^","o"],s= 150)  # Scatter plot
# Out:
# <Axes: xlabel='Loan Amount', ylabel='Income'>

# %%
# Step 2: Preparing the dataset
A = loan['Default']
B = loan[['Income', 'Loan Amount']]

x_train, x_test, y_train, y_test = train_test_split(B, A, train_size=0.8,stratify=A, random_state = 1234)

print(x_train.shape)
print(x_test.shape)
# Out:
# (24, 2)
# (6, 2)

# %%
Classifier = DecisionTreeClassifier(random_state=100).fit(x_train,y_train)
score = Classifier.score(x_test, y_test) * 100
print('Accuracy of Decision Tree classifier on the test set: %.2f%%' % score)
# Out:
# Accuracy of Decision Tree classifier on the test set: 50.00%

# %%
# Visualizing the tree
plt.figure(figsize=(15,15))
tree.plot_tree(Classifier,feature_names=list(B),class_names=['No','Yes'],filled = True) # the model in deescription is the decision tree object(classifier)
plt.show()
